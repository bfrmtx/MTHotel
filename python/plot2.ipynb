# %%
from pathlib import Path
import sys
import importlib

base_dir = Path(__file__).resolve().parent if "__file__" in globals() else Path.cwd()
if str(base_dir) not in sys.path:
    sys.path.insert(0, str(base_dir))

import atss.atsslib as atsslib_module
atsslib_module = importlib.reload(atsslib_module)

channel = atsslib_module.channel
resolve_file_path = atsslib_module.resolve_file_path
plot_ts = atsslib_module.plot_ts
fft_quick = atsslib_module.fft_quick
plot_fft = atsslib_module.plot_fft
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 9
#       5 base_dir = Path(__file__).resolve().parent if "__file__" in globals() else Path.cwd()
#       6 if str(base_dir) not in sys.path:
#       7     sys.path.insert(0, str(base_dir))
#       8
# ----> 9 import atsslib.atsslib as atsslib_module
#      10 atsslib_module = importlib.reload(atsslib_module)
#      11
#      12 channel = atsslib_module.channel
#
# ModuleNotFoundError: No module named 'atsslib'

# %%
channels = []
ch1 = channel("/survey/4x4xatss/stations/65k/run_005/014_ADU-11e_C002_THx_256Hz")
channels.append(ch1)
ch2 = channel("/survey/4x4xpy/stations/65k/run_007/014_ADU-11e_C002_THx_256Hz")
channels.append(ch2)

# %%
from bokeh.plotting import figure, show
plot_ts(channels, 0, 64)
# Out:
#   <div id="a766f58a-d033-4c23-a656-38c3062500a0" data-root-id="p1657" style="display: contents;"></div>
# figure(id='p1657', ...)

# %%
print(f"Path      : {ch1.path}")
# print(f"Header    : {ch1.header}")
print(f"Cal sensor: {ch1.calibration['sensor']}")
print(f"Timing    : {ch1.timing_info()}")
print(f"Samples   : {ch1.get_samples()}")
print("and for ch2")
print(f"Path      : {ch2.path}")
# print(f"Header    : {ch2.header}")
print(f"Cal sensor: {ch2.calibration['sensor']}")
print(f"Timing    : {ch2.timing_info()}")
print(f"Samples   : {ch2.get_samples()}")
print("original")
ch0 = channel("/survey/4x4atss/stations/65k/run_004/014_ADU-11e_C002_THx_1024Hz")
print(f"Path      : {ch0.path}")
print(f"Samples   : {ch0.get_samples()}")
print("compare samples, ch0, ch0 / 4, ch1, ch2")
print(f"ch0: {ch0.get_samples()}, ch0/4: {ch0.get_samples()//4}, ch1: {ch1.get_samples()}, ch2: {ch2.get_samples()}")
# Out:
# Path      : /survey/4x4atss/stations/65k/run_005/014_ADU-11e_C002_THx_256Hz
# Cal sensor: MFS-07e
# Timing    : Start: 2026-05-21T10:04:39, Stop: 2026-05-21T11:47:03, Duration: 01:42:24.00 (6144.00 seconds)
# Samples   : 1572864
# and for ch2
# Path      : /survey/4x4py/stations/65k/run_005/014_ADU-11e_C002_THx_256Hz
# Cal sensor: MFS-07e
# Timing    : Start: 2026-05-21T10:04:38.964844, Stop: 2026-05-21T12:12:37.933594, Duration: 02:07:58.97 (7678.97 seconds)
# Samples   : 1965816
# original
# Path      : /survey/4x4atss/stations/65k/run_004/014_ADU-11e_C002_THx_1024Hz
# Samples   : 7864320
# compare samples, ch0, ch0 / 4, ch1, ch2
# ch0: 7864320, ch0/4: 1966080, ch1: 1572864, ch2: 1965816
